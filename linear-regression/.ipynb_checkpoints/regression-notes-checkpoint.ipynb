# %% [markdown]
# # Linear Regression
# Here are collection of codes for [linear regression blogpost](https://chuanfuyap.github.io/2022/10/13/linear-regression)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# %%
hw = pd.read_csv("data/student_height_weight.txt", sep='\t')
plt.Figure(dpi=80)
sns.lmplot(x='ht', y='wt', data=hw, scatter_kws={"color": "'cyan'"}, line_kws={"color": "red"})
plt.xlabel("Height (inches)")
plt.ylabel("Weight (lbs)")
plt.savefig('ht_wt1.png')

# %%
hw = pd.read_csv("data/Howell1.csv", sep=';')
plt.Figure(dpi=80)
sns.lmplot(x='height', y='weight', data=hw)
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.savefig('ht_wt2.png')
